# %%
import inspect
from os import path, sys

currentdir = path.dirname(path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = path.dirname(currentdir)
grandparentdir = path.dirname(parentdir)

sys.path.append(grandparentdir)

# %%
from graph import DenseGraphBuilder
from graph_tool.all import *

# %%
g = DenseGraphBuilder()\
    .with_n(200)\
    .with_m(200)\
    .build()

graph_draw(g, vertex_text=g.vertex_index, vertex_font_size=12, output_size=(1000, 1000))
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x12892f710, at 0x12892f9d0>
