# %%
import sys
import inspect
from os import path
sys.path.insert(0, path.abspath(path.join(path.dirname(inspect.getfile(inspect.currentframe())), '../..')))

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import random

from tools.plot import bland_altman_plot

# %%
df1 = pd.read_csv('../results/complete_graph_exact.csv')
df2 = pd.read_csv('../results/complete_graph_grasp.csv')

# %%
plt.clf()
bland_altman_plot(df1['result'], df2['result'])
plt.show()
