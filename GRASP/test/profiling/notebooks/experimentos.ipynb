# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import random

import math

# %%
df1 = pd.read_csv('../../../../datos/comp-algoritmos-con-exacto-variando-m.csv', sep=', ', engine='python')

ax1 = df1.plot(kind='line', x='m', y='fronteraExacto', grid=True, label="Frontera Exacto")
ax1 = df1.plot(kind='line', x='m', y='fronteraHConstructiva', color='g', grid=True, label="Frontera H. Constr.", ax = ax1)
ax1 = df1.plot(kind='line', x='m', y='fronteraBLocal', color='r', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df1.plot(kind='line', x='m', y='fronteraGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.title('Grafos tipo random')
plt.ylabel(r'Frontera')
plt.savefig('../../../../pics/fronteras-comp-algoritmos-con-exacto-variando-m.png')
plt.show()

# %%
df_non_grasp = pd.read_csv('../../../../datos/comp-algoritmos-con-exacto-variando-m.csv', sep=', ', engine='python')
ax1 = df_non_grasp.plot(kind='line', x='m', y='fronteraHConstructiva', color='g', grid=True, label="Frontera H. Constr.")
ax1 = df_non_grasp.plot(kind='line', x='m', y='fronteraBLocal', color='r', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df_non_grasp.plot(kind='line', x='m', y='fronteraExacto', grid=True, label="Frontera Exacto", ax = ax1)
plt.title('Grafos tipo random')
plt.ylabel(r'Frontera')
plt.savefig('../../../../pics/fronteras-comp-no-grasp-con-exacto-variando-m.png')
plt.show()

# %%
df_grasp_exacto = pd.read_csv('../../../../datos/comp-algoritmos-con-exacto-variando-m.csv', sep=', ', engine='python')
ax1 = df_grasp_exacto.plot(kind='line', x='m', y='fronteraExacto', grid=True, label="Frontera Exacto")
ax1 = df_grasp_exacto.plot(kind='line', x='m', y='fronteraGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.title('Grafos tipo random')
plt.ylabel(r'Frontera')
plt.savefig('../../../../pics/fronteras-comp-grasp-con-exacto-variando-m.png')
plt.show()

# %%
df_grasp_pearson = pd.read_csv('../../../../datos/comp-algoritmos-con-exacto-variando-m.csv', sep=', ', engine='python')

sns.jointplot(df_grasp_pearson['fronteraExacto'], df_grasp_pearson['fronteraGrasp'], kind="reg")
plt.xlabel(r'Frontera exacto')
plt.ylabel(r'Frontera GRASP')
plt.savefig('../../../../pics/fronteras-comp-reg-grasp-exacto-variando-m.png')
plt.show()

# %%
df2 = pd.read_csv('../../../../datos/comp-algoritmos-con-exacto-variando-m.csv', sep=', ', engine='python')
df2.drop(['fronteraExacto'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraHConstructiva'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraBLocal'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraGrasp'], axis = 1, inplace = True, errors = 'ignore')
# print(df2)
dots_size=4
ax1 = df2.plot(kind='line',  x='m', y='tiempoExacto', grid=True, label="Frontera Exacto")
ax1 = df2.plot(kind='line',  x='m', y='tiempoHConstructiva', color='r', grid=True, label="Frontera H. Constr.", ax = ax1)
ax1 = df2.plot(kind='line', x='m', y='tiempoBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df2.plot(kind='line', x='m', y='tiempoGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.title('Grafos tipo random')
plt.ylabel(r'Tiempo(ns)')
plt.yscale('log')
plt.savefig('../../../../pics/tiempos-comp-algoritmos-con-exacto-variando-m.png')
plt.show()

# %%
df3 = pd.read_csv('../../../../datos/comp-algoritmos-sin-exacto-variando-m.csv', sep=', ', engine='python')
# print(df1.columns.tolist())
dots_size=4
ax1 = df3.plot(kind='line', x='m', y='fronteraHConstructiva', color='r', grid=True, label="Frontera H. Constr.")
ax1 = df3.plot(kind='line', x='m', y='fronteraBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df3.plot(kind='line', x='m', y='fronteraGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.ylabel(r'Frontera')
plt.title('Grafos tipo random')
plt.savefig('../../../../pics/fronteras-comp-algoritmos-sin-exacto-variando-m.png')
plt.show()

# %%
df2 = pd.read_csv('../../../../datos/comp-algoritmos-sin-exacto-variando-m.csv', sep=', ', engine='python')
df2.drop(['fronteraExacto'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraHConstructiva'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraBLocal'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraGrasp'], axis = 1, inplace = True, errors = 'ignore')
# print(df2)
dots_size=4
ax1 = df2.plot(kind='line',  x='m', y='tiempoHConstructiva', color='r', grid=True, label="Frontera H. Constr.")
ax1 = df2.plot(kind='line', x='m', y='tiempoBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df2.plot(kind='line', x='m', y='tiempoGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.title('Grafos tipo random')
plt.ylabel(r'Tiempo(ns)')
plt.yscale('log')
plt.savefig('../../../../pics/tiempos-comp-algoritmos-sin-exacto-variando-m.png')
plt.show()

# %%
df4 = pd.read_csv('../../../../datos/comp-algoritmos-sin-exacto-variando-n-mcompleto.csv', sep=', ', engine='python')
# print(df1.columns.tolist())
dots_size=4
ax1 = df4.plot(kind='scatter', s=dots_size+150, x='n', y='fronteraExacto', color='b', grid=True, label="Frontera Real")
ax1 = df4.plot(kind='scatter', s=dots_size+100, x='n', y='fronteraHConstructiva', color='r', grid=True, label="Frontera H. Constr.", ax = ax1)
ax1 = df4.plot(kind='scatter', s=dots_size+50, x='n', y='fronteraBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df4.plot(kind='scatter', s=dots_size, x='n', y='fronteraGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.ylabel(r'Frontera')
plt.title('Grafos tipo completo')
plt.savefig('../../../../pics/fronteras-comp-algoritmos-sin-exacto-variando-n-mcompleto.png')
plt.show()

# %%
data = pd.DataFrame(data={
    'Algoritmo': ['Greedy', 'Búsqueda Local', 'GRASP'],
    'Porcentaje de acierto mínimo': [
        (df4['fronteraHConstructiva'] / df4['fronteraExacto']).min(), 
        (df4['fronteraBLocal'] / df4['fronteraExacto']).min(),
        (df4['fronteraGrasp'] / df4['fronteraExacto']).min()
    ]
})

data.to_csv('../../../../datos/fonteras-comp-algoritmos-sin-exacto-variando-n-completo-aciertos.csv')

print(data.to_latex())

data
# Out:
# \begin{tabular}{llr}
# \toprule
# {} &       Algoritmo &  Porcentaje de acierto mínimo \\
# \midrule
# 0 &          Greedy &                           1.0 \\
# 1 &  Búsqueda Local &                           1.0 \\
# 2 &           GRASP &                           1.0 \\
# \bottomrule
# \end{tabular}
#         Algoritmo  Porcentaje de acierto mínimo
# 0          Greedy                           1.0
# 1  Búsqueda Local                           1.0
# 2           GRASP                           1.0

# %%
df2 = pd.read_csv('../../../../datos/comp-algoritmos-sin-exacto-variando-n-mcompleto.csv', sep=', ', engine='python')
df2.drop(['fronteraExacto'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraHConstructiva'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraBLocal'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraGrasp'], axis = 1, inplace = True, errors = 'ignore')
# print(df2)
dots_size=4
ax1 = df2.plot(kind='line',  x='m', y='tiempoHConstructiva', color='r', grid=True, label="Frontera H. Constr.")
ax1 = df2.plot(kind='line', x='m', y='tiempoBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df2.plot(kind='line', x='m', y='tiempoGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.title('Grafos tipo completo')
plt.ylabel(r'Tiempo(ns)')
plt.yscale('log')
plt.savefig('../../../../pics/tiempos-comp-algoritmos-sin-exacto-variando-n-mcompleto.png')
plt.show()

# %%
df5 = pd.read_csv('../../../../datos/comp-algoritmos-sin-exacto-variando-k-caso-malo-blocal-hconstructiva.csv', sep=', ', engine='python')
# print(df1.columns.tolist())
dots_size=4
ax1 = df5.plot(kind='scatter', s=dots_size+50, x='k', y='fronteraExacto', grid=True, label="Frontera Real")
ax1 = df5.plot(kind='scatter', s=dots_size+50, x='k', y='fronteraHConstructiva', color='r', grid=True, label="Frontera H. Constr.", ax = ax1)
ax1 = df5.plot(kind='scatter', s=dots_size+5, x='k', y='fronteraBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df5.plot(kind='scatter', s=dots_size+5, x='k', y='fronteraGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.ylabel(r'Frontera')
plt.title("Grafos tipo $figura$ $6$ (1 estrella)")
plt.savefig('../../../../pics/fronteras-comp-algoritmos-sin-exacto-variando-k-caso-malo-blocal-hconstructiva.png')
plt.show()

# %%
data = pd.DataFrame(data={
    'Algoritmo': ['Greedy', 'Busqueda Local', 'GRASP'],
    'Porcentaje de acierto minimo': [
        (df5['fronteraHConstructiva'] / df5['fronteraExacto']).min(), 
        (df5['fronteraBLocal'] / df5['fronteraExacto']).min(),
        (df5['fronteraGrasp'] / df5['fronteraExacto']).min()
    ]
})


print(data.to_latex())

data
# Out:
# \begin{tabular}{llr}
# \toprule
# {} &       Algoritmo &  Porcentaje de acierto minimo \\
# \midrule
# 0 &          Greedy &                      0.500201 \\
# 1 &  Busqueda Local &                      0.500201 \\
# 2 &           GRASP &                      1.000000 \\
# \bottomrule
# \end{tabular}

# %%
data = pd.DataFrame(data={
    'Promedio de mejora de búsqueda local respecto a greedy': [
        (df5['fronteraBLocal'] - df5['fronteraHConstructiva']).mean(),
    ]
})

print(data.to_latex())

data
# Out:
# \begin{tabular}{lr}
# \toprule
# {} &  Promedio de mejora de búsqueda local respecto a greedy \\
# \midrule
# 0 &                                                0.0 \\
# \bottomrule
# \end{tabular}
#    Promedio de mejora de búsqueda local respecto a greedy
# 0                                                0.0

# %%
df2 = pd.read_csv('../../../../datos/comp-algoritmos-sin-exacto-variando-k-caso-malo-blocal-hconstructiva.csv', sep=', ', engine='python')
df2.drop(['fronteraExacto'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraHConstructiva'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraBLocal'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraGrasp'], axis = 1, inplace = True, errors = 'ignore')
# print(df2)
dots_size=4
ax1 = df2.plot(kind='line',  x='k', y='tiempoHConstructiva', color='r', grid=True, label="Frontera H. Constr.")
ax1 = df2.plot(kind='line', x='k', y='tiempoBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df2.plot(kind='line', x='k', y='tiempoGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.title("Grafos tipo $figura$ $6$ (1 estrella)")
plt.ylabel(r'Tiempo(ns)')
plt.yscale('log')
plt.savefig('../../../../pics/tiempos-comp-algoritmos-sin-exacto-variando-k-caso-malo-blocal-hconstructiva.png')
plt.show()

# %%
df6 = pd.read_csv('../../../../datos/comp-algoritmos-sin-exacto-variando-k-caso-malo-todos.csv', sep=', ', engine='python')
# print(df1.columns.tolist())
dots_size=4
ax1 = df6.plot(kind='scatter', s=dots_size, x='k', y='fronteraExacto', grid=True, label="Frontera Real")
ax1 = df6.plot(kind='scatter', s=dots_size+80, x='k', y='fronteraHConstructiva', color='r', grid=True, label="Frontera H. Constr.", ax = ax1)
ax1 = df6.plot(kind='scatter', s=dots_size+20, x='k', y='fronteraBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df6.plot(kind='scatter', s=dots_size, x='k', y='fronteraGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.title('Grafos tipo $figura$ $6$ (4 estrellas)')
plt.ylabel(r'Frontera')
plt.savefig('../../../../pics/fronteras-comp-algoritmos-sin-exacto-variando-k-caso-malo-todos.png')
plt.show()

# %%
df2 = pd.read_csv('../../../../datos/comp-algoritmos-sin-exacto-variando-k-caso-malo-todos.csv', sep=', ', engine='python')
df2.drop(['fronteraExacto'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraHConstructiva'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraBLocal'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraGrasp'], axis = 1, inplace = True, errors = 'ignore')
# print(df2)
dots_size=4
ax1 = df2.plot(kind='line',  x='k', y='tiempoHConstructiva', color='r', grid=True, label="Frontera H. Constr.")
ax1 = df2.plot(kind='line', x='k', y='tiempoBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df2.plot(kind='line', x='k', y='tiempoGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.title("Grafos tipo $figura$ $6$ (4 estrella)")
plt.ylabel(r'Tiempo(ns)')
plt.yscale('log')
plt.savefig('../../../../pics/tiempos-comp-algoritmos-sin-exacto-variando-k-caso-malo-todos.png')
plt.show()

# %%
data = pd.DataFrame(data={
    'Error promedio': [((df6['fronteraExacto'] - df6['fronteraBLocal']) / df6['fronteraExacto']).mean()],
    'Promedio de mejora de b. local sobre Greedy': [(df6['fronteraBLocal'] - df6['fronteraHConstructiva']).mean()],
    'Promedio de mejora de GRASP sobre b. local': [(df6['fronteraGrasp'] - df6['fronteraBLocal']).mean()]
})


print(data.to_latex())

data
# Out:
# \begin{tabular}{lrrr}
# \toprule
# {} &  Error promedio &  Promedio de mejora de GRASP sobre b. local &  Promedio de mejora de b. local sobre Greedy \\
# \midrule
# 0 &         0.49691 &                                         0.0 &                                          0.0 \\
# \bottomrule
# \end{tabular}
#    Error promedio  Promedio de mejora de GRASP sobre b. local  \
# 0         0.49691                                         0.0
#
#    Promedio de mejora de b. local sobre Greedy
# 0                                          0.0

# %%
df6 = pd.read_csv('../../../../datos/comp-algoritmos-sin-exacto-variando-n-caso-malo-hconstructiva-bueno-blocal.csv', sep=', ', engine='python')
# print(df1.columns.tolist())
dots_size=4
ax1 = df6.plot(kind='scatter', s=dots_size+100, x='n', y='fronteraExacto', grid=True, label="Frontera Real")
ax1 = df6.plot(kind='scatter', s=dots_size, x='n', y='fronteraHConstructiva', color='g', grid=True, label="Frontera H. Constr.", ax = ax1)
ax1 = df6.plot(kind='scatter', s=dots_size+20, x='n', y='fronteraBLocal', color='r', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df6.plot(kind='scatter', s=dots_size, x='n', y='fronteraGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.title('Grafos tipo $figura$ $5$')
plt.ylabel(r'Frontera')
plt.savefig('../../../../pics/frontera-comp-algoritmos-sin-exacto-variando-n-caso-malo-hconstructiva-bueno-blocal.png')
plt.show()

# %%
data = pd.DataFrame(data={
    'Algoritmo': ['Greedy', 'Búsqueda Local', 'GRASP'],
    'Porcentaje de acierto mínimo': [
        (df6['fronteraHConstructiva'] / df6['fronteraExacto']).min(), 
        (df6['fronteraBLocal'] / df6['fronteraExacto']).min(),
        (df6['fronteraGrasp'] / df6['fronteraExacto']).min()
    ],
    'Porcentaje de acierto máximo': [
        (df6['fronteraHConstructiva'] / df6['fronteraExacto']).max(), 
        (df6['fronteraBLocal'] / df6['fronteraExacto']).max(),
        (df6['fronteraGrasp'] / df6['fronteraExacto']).max()
    ],
    'Porcentaje de acierto promedio': [
        (df6['fronteraHConstructiva'] / df6['fronteraExacto']).mean(), 
        (df6['fronteraBLocal'] / df6['fronteraExacto']).mean(),
        (df6['fronteraGrasp'] / df6['fronteraExacto']).mean()
    ],
})

print(data.to_latex())

data
# Out:
# \begin{tabular}{llrrr}
# \toprule
# {} &       Algoritmo &  Porcentaje de acierto máximo &  Porcentaje de acierto mínimo &  Porcentaje de acierto promedio \\
# \midrule
# 0 &          Greedy &                           1.0 &                      0.005692 &                        0.039095 \\
# 1 &  Búsqueda Local &                           1.0 &                      1.000000 &                        1.000000 \\
# 2 &           GRASP &                           1.0 &                      1.000000 &                        1.000000 \\
# \bottomrule
# \end{tabular}
#         Algoritmo  Porcentaje de acierto máximo  Porcentaje de acierto mínimo  \
# 0          Greedy                           1.0                      0.005692
# 1  Búsqueda Local                           1.0                      1.000000
# 2           GRASP                           1.0                      1.000000
#
#    Porcentaje de acierto promedio
# 0                        0.039095
# ...

# %%
df2 = pd.read_csv('../../../../datos/comp-algoritmos-sin-exacto-variando-k-caso-malo-blocal-bueno-hconstructiva.csv', sep=', ', engine='python')
df2.drop(['fronteraExacto'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraHConstructiva'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraBLocal'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraGrasp'], axis = 1, inplace = True, errors = 'ignore')
# print(df2)
dots_size=4
ax1 = df2.plot(kind='line',  x='k', y='tiempoHConstructiva', color='r', grid=True, label="Frontera H. Constr.")
ax1 = df2.plot(kind='line', x='k', y='tiempoBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df2.plot(kind='line', x='k', y='tiempoGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.title("Grafos tipo $figura$ $6$ (1 estrella)")
plt.ylabel(r'Tiempo(ns)')
plt.yscale('log')
plt.savefig('../../../../pics/tiempos-comp-algoritmos-sin-exacto-variando-k-caso-malo-blocal-hconstructiva.png')
plt.show()
