# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import random

import math

# %%
df1 = pd.read_csv('../../../../datos/comp-algoritmos-con-exacto-variando-m.csv', sep=', ', engine='python')
# print(df1.columns.tolist())
dots_size=4
ax1 = df1.plot(kind='scatter', s=dots_size, x='m', y='fronteraExacto', grid=True, label="Frontera Exacto")
ax1 = df1.plot(kind='scatter', s=dots_size, x='m', y='fronteraHConstructiva', color='r', grid=True, label="Frontera H. Constr.", ax = ax1)
ax1 = df1.plot(kind='scatter', s=dots_size, x='m', y='fronteraBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df1.plot(kind='scatter', s=dots_size, x='m', y='fronteraGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.title('Prom. fronteras')
plt.ylabel(r'Frontera')
plt.savefig('../../../../pics/fronteras-comp-algoritmos-con-exacto-variando-m.png')
plt.show()

# %%
df2 = pd.read_csv('../../../../datos/comp-algoritmos-con-exacto-variando-m.csv', sep=', ', engine='python')
df2.drop(['fronteraExacto'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraHConstructiva'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraBLocal'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['fronteraGrasp'], axis = 1, inplace = True, errors = 'ignore')
# print(df2)
dots_size=4
ax1 = df2.plot(kind='scatter', s=dots_size, x='m', y='tiempoExacto', grid=True, label="Frontera Exacto")
ax1 = df2.plot(kind='scatter', s=dots_size, x='m', y='tiempoHConstructiva', color='r', grid=True, label="Frontera H. Constr.", ax = ax1)
ax1 = df2.plot(kind='scatter', s=dots_size, x='m', y='tiempoBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df2.plot(kind='scatter', s=dots_size, x='m', y='tiempoGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.title('Tiempos')
plt.ylabel(r'Tiempo(ns)')
plt.yscale('symlog')
plt.savefig('../../../../pics/tiempos-comp-algoritmos-con-exacto-variando-m.png')
plt.show()

# %%
df3 = pd.read_csv('../../../../datos/comp-algoritmos-sin-exacto-variando-m.csv', sep=', ', engine='python')
# print(df1.columns.tolist())
dots_size=4
ax1 = df3.plot(kind='scatter', s=dots_size, x='m', y='fronteraHConstructiva', color='r', grid=True, label="Frontera H. Constr.")
ax1 = df3.plot(kind='scatter', s=dots_size, x='m', y='fronteraBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df3.plot(kind='scatter', s=dots_size, x='m', y='fronteraGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.ylabel(r'Frontera')
plt.savefig('../../../../pics/fronteras-comp-algoritmos-sin-exacto-variando-m.png')
plt.show()

# %%
df4 = pd.read_csv('../../../../datos/comp-algoritmos-sin-exacto-variando-n-mcompleto.csv', sep=', ', engine='python')
# print(df1.columns.tolist())
dots_size=4
ax1 = df4.plot(kind='scatter', s=dots_size, x='n', y='fronteraHConstructiva', color='r', grid=True, label="Frontera H. Constr.")
ax1 = df4.plot(kind='scatter', s=dots_size, x='n', y='fronteraBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df4.plot(kind='scatter', s=dots_size, x='n', y='fronteraGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.ylabel(r'Frontera')
plt.savefig('../../../../pics/fronteras-comp-algoritmos-sin-exacto-variando-n-mcompleto.png')
plt.show()

# %%
df5 = pd.read_csv('../../../../datos/comp-algoritmos-sin-exacto-variando-k-caso-malo-blocal-hconstructiva.csv', sep=', ', engine='python')
# print(df1.columns.tolist())
dots_size=4
ax1 = df5.plot(kind='scatter', s=dots_size, x='k', y='fronteraExacto', grid=True, label="Frontera Exacto")
ax1 = df5.plot(kind='scatter', s=dots_size, x='k', y='fronteraHConstructiva', color='r', grid=True, label="Frontera H. Constr.", ax = ax1)
ax1 = df5.plot(kind='scatter', s=dots_size, x='k', y='fronteraBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df5.plot(kind='scatter', s=dots_size, x='k', y='fronteraGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.ylabel(r'Frontera')
plt.savefig('../../../../pics/fronteras-comp-algoritmos-sin-exacto-variando-k-caso-malo-blocal-hconstructiva.png')
plt.show()

# %%
df6 = pd.read_csv('../../../../datos/comp-algoritmos-sin-exacto-variando-k-caso-malo-todos.csv', sep=', ', engine='python')
# print(df1.columns.tolist())
dots_size=4
ax1 = df6.plot(kind='scatter', s=dots_size, x='k', y='fronteraExacto', grid=True, label="Frontera Exacto")
ax1 = df6.plot(kind='scatter', s=dots_size, x='k', y='fronteraHConstructiva', color='r', grid=True, label="Frontera H. Constr.", ax = ax1)
ax1 = df6.plot(kind='scatter', s=dots_size, x='k', y='fronteraBLocal', color='g', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df6.plot(kind='scatter', s=dots_size, x='k', y='fronteraGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
plt.title('Prom. fronteras')
plt.ylabel(r'Frontera')
plt.savefig('../../../../pics/comp-algoritmos-sin-exacto-variando-k-caso-malo-todos.png')
plt.show()
